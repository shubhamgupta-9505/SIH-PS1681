# %%
import pandas as pd

# %%
df=pd.read_csv("new_df1_12.csv")

# %%
new_df=pd.read_csv("updated_df_2_features_10000_parallel.csv")

# %%
df.head()
# Out:
#              0            1   2  \
# 0  BlockCipher      AES-128   1
# 1  BlockCipher   Triple-DES   1
# 2  BlockCipher     Blowfish   1
# 3  BlockCipher     CAST-128   1
# 4  BlockCipher      AES-128   2
#
#                                                    3       algorithm  \
# 0  0ac1d7274c1f90b0f386d76bb84ef47990afc2c90e70c6...      AES-128_ 1
# 1  fb33c1f018339f01427793223992dc964bc04c064a98c8...   Triple-DES_ 1
# 2  d3e59d4c6b095083075fe1620fa371fd496e008db1d0bf...     Blowfish_ 1
# 3  7d29e9cc5422da3f2a3f69fae4dbdaa7f3ee17ec8bd96b...     CAST-128_ 1
# 4  a3aa833397ceb8ecb3d564a537928ae1f43da04973783b...      AES-128_ 2
#
#                                                    4  entropy_128  \
# 0  0000000000001010000011000000000100001101000001...     0.757878
# 1  0000111100001011000000110000001100001100000000...     0.798659
# 2  0000110100000011000011100000010100001001000011...     0.785560
# 3  0000011100001101000000100000100100001110000010...     0.835116
# ...

# %%
new_df.head()
# Out:
#    Unnamed: 0            0           1    2  \
# 0           0  BlockCipher     AES-128  1.0
# 1           1  BlockCipher     AES-192  1.0
# 2           2  BlockCipher     AES-256  1.0
# 3           3  BlockCipher  Triple-DES  1.0
# 4           4  BlockCipher    Blowfish  1.0
#
#                                                    3  \
# 0  dd31d143c7a874404f923350c5f3b71f7b22114e59fc05...
# 1  0873cdd9722a4f21058b784cf46cb608e91f2cd3cd39e1...
# 2  5df31906ab000602d1fc26ff41b866ed494e82d39716cd...
# 3  678db4270c1391f12471c9a94f196a5b256ff21b32a626...
# 4  4612d96b228d9abcb8295343ddc3759287f0a193941783...
#
#                                                    4  entropy_128  \
# 0  0000110100001101000000110000000100001101000000...     0.771971
# 1  0000000000001000000001110000001100001100000011...     0.785560
# 2  0000010100001101000011110000001100000001000010...     0.696212
# 3  0000011000000111000010000000110100001011000001...     0.785560
# ...

# %%
copy_df=df.copy()

# %%
copy_df.drop(columns=['algorithm_encoded'], inplace=True)

# %%
copy_df.head()
# Out:
#              0            1   2  \
# 0  BlockCipher      AES-128   1
# 1  BlockCipher   Triple-DES   1
# 2  BlockCipher     Blowfish   1
# 3  BlockCipher     CAST-128   1
# 4  BlockCipher      AES-128   2
#
#                                                    3       algorithm  \
# 0  0ac1d7274c1f90b0f386d76bb84ef47990afc2c90e70c6...      AES-128_ 1
# 1  fb33c1f018339f01427793223992dc964bc04c064a98c8...   Triple-DES_ 1
# 2  d3e59d4c6b095083075fe1620fa371fd496e008db1d0bf...     Blowfish_ 1
# 3  7d29e9cc5422da3f2a3f69fae4dbdaa7f3ee17ec8bd96b...     CAST-128_ 1
# 4  a3aa833397ceb8ecb3d564a537928ae1f43da04973783b...      AES-128_ 2
#
#                                                    4  entropy_128  \
# 0  0000000000001010000011000000000100001101000001...     0.757878
# 1  0000111100001011000000110000001100001100000000...     0.798659
# 2  0000110100000011000011100000010100001001000011...     0.785560
# 3  0000011100001101000000100000100100001110000010...     0.835116
# ...

# %%
new_df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
new_df.head()
# Out:
#              0           1    2  \
# 0  BlockCipher     AES-128  1.0
# 1  BlockCipher     AES-192  1.0
# 2  BlockCipher     AES-256  1.0
# 3  BlockCipher  Triple-DES  1.0
# 4  BlockCipher    Blowfish  1.0
#
#                                                    3  \
# 0  dd31d143c7a874404f923350c5f3b71f7b22114e59fc05...
# 1  0873cdd9722a4f21058b784cf46cb608e91f2cd3cd39e1...
# 2  5df31906ab000602d1fc26ff41b866ed494e82d39716cd...
# 3  678db4270c1391f12471c9a94f196a5b256ff21b32a626...
# 4  4612d96b228d9abcb8295343ddc3759287f0a193941783...
#
#                                                    4  entropy_128  \
# 0  0000110100001101000000110000000100001101000000...     0.771971
# 1  0000000000001000000001110000001100001100000011...     0.785560
# 2  0000010100001101000011110000001100000001000010...     0.696212
# 3  0000011000000111000010000000110100001011000001...     0.785560
# 4  0000010000000110000000010000001000001101000010...     0.785560
#
# ...

# %%
copy_df.drop(columns=['algorithm'], inplace=True)

# %%
copy_df.head()
# Out:
#              0            1   2  \
# 0  BlockCipher      AES-128   1
# 1  BlockCipher   Triple-DES   1
# 2  BlockCipher     Blowfish   1
# 3  BlockCipher     CAST-128   1
# 4  BlockCipher      AES-128   2
#
#                                                    3  \
# 0  0ac1d7274c1f90b0f386d76bb84ef47990afc2c90e70c6...
# 1  fb33c1f018339f01427793223992dc964bc04c064a98c8...
# 2  d3e59d4c6b095083075fe1620fa371fd496e008db1d0bf...
# 3  7d29e9cc5422da3f2a3f69fae4dbdaa7f3ee17ec8bd96b...
# 4  a3aa833397ceb8ecb3d564a537928ae1f43da04973783b...
#
#                                                    4  entropy_128  \
# 0  0000000000001010000011000000000100001101000001...     0.757878
# 1  0000111100001011000000110000001100001100000000...     0.798659
# 2  0000110100000011000011100000010100001001000011...     0.785560
# 3  0000011100001101000000100000100100001110000010...     0.835116
# 4  0000101000000011000010100000101000001000000000...     0.835116
#
# ...

# %%
new_df.head()
# Out:
#              0           1    2  \
# 0  BlockCipher     AES-128  1.0
# 1  BlockCipher     AES-192  1.0
# 2  BlockCipher     AES-256  1.0
# 3  BlockCipher  Triple-DES  1.0
# 4  BlockCipher    Blowfish  1.0
#
#                                                    3  \
# 0  dd31d143c7a874404f923350c5f3b71f7b22114e59fc05...
# 1  0873cdd9722a4f21058b784cf46cb608e91f2cd3cd39e1...
# 2  5df31906ab000602d1fc26ff41b866ed494e82d39716cd...
# 3  678db4270c1391f12471c9a94f196a5b256ff21b32a626...
# 4  4612d96b228d9abcb8295343ddc3759287f0a193941783...
#
#                                                    4  entropy_128  \
# 0  0000110100001101000000110000000100001101000000...     0.771971
# 1  0000000000001000000001110000001100001100000011...     0.785560
# 2  0000010100001101000011110000001100000001000010...     0.696212
# 3  0000011000000111000010000000110100001011000001...     0.785560
# 4  0000010000000110000000010000001000001101000010...     0.785560
#
# ...

# %%
set(new_df.columns)-set(copy_df.columns)
# Out:
# set()

# %% [markdown]
# new_df and copy_df are to be combined algothms

# %%
new_df['1'].unique()
# Out:
# array(['AES-128', 'AES-192', 'AES-256', 'Triple-DES', 'Blowfish',
#        'CAST-128', 'Blake', 'Keccak', 'ARC4', 'ChaCha20', 'Salsa20'],
#       dtype=object)

# %%
copy_df['1'].unique()
# Out:
# array([' AES-128', ' Triple-DES', ' Blowfish', ' CAST-128', ' Blake',
#        ' Keccak', ' ARC4', ' ChaCha20', ' Salsa20'], dtype=object)

# %%
new_df = new_df[(new_df['1'] != 'AES-192') & (new_df['1'] != 'AES-256')]

# %%
new_df.shape
# Out:
# (35713, 299)

# %%
copy_df.shape
# Out:
# (25025, 299)

# %%
copy_df_1=copy_df.copy()

# %%
new_df_1=new_df.copy()

# %%
combined_df = pd.concat([copy_df_1, new_df_1], axis=0)

# %%
combined_df.shape
# Out:
# (60738, 299)

# %%
combined_df.head()
# Out:
#              0            1   2  \
# 0  BlockCipher      AES-128   1
# 1  BlockCipher   Triple-DES   1
# 2  BlockCipher     Blowfish   1
# 3  BlockCipher     CAST-128   1
# 4  BlockCipher      AES-128   2
#
#                                                    3  \
# 0  0ac1d7274c1f90b0f386d76bb84ef47990afc2c90e70c6...
# 1  fb33c1f018339f01427793223992dc964bc04c064a98c8...
# 2  d3e59d4c6b095083075fe1620fa371fd496e008db1d0bf...
# 3  7d29e9cc5422da3f2a3f69fae4dbdaa7f3ee17ec8bd96b...
# 4  a3aa833397ceb8ecb3d564a537928ae1f43da04973783b...
#
#                                                    4  entropy_128  \
# 0  0000000000001010000011000000000100001101000001...     0.757878
# 1  0000111100001011000000110000001100001100000000...     0.798659
# 2  0000110100000011000011100000010100001001000011...     0.785560
# 3  0000011100001101000000100000100100001110000010...     0.835116
# 4  0000101000000011000010100000101000001000000000...     0.835116
#
# ...

# %%
combined_df.to_csv("combine_df_trial.csv")
