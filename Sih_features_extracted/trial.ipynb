# %%
import pandas as pd

# %%
df=pd.read_csv("updated_csv_full_parallel_10000.csv",header=None)

# %%
df[3].apply(len).unique()
# Out:
# array([20032,   128,    64, 20020, 20026, 20064, 20056, 20016, 20004,
#        20048, 20040, 20000, 20096, 20080, 20068, 20160, 20144, 20140,
#        20006, 20012, 20034, 20060, 20022, 20014, 20024, 20062, 20002,
#        20086, 20010, 20082, 20036, 20088, 20030, 20008, 20038, 20066,
#        20018, 20058, 20042, 20052, 20054, 20050, 20078, 20074, 20028,
#        20076, 20128, 20112, 20102, 20046, 20256, 20240, 20232, 20136,
#        20126, 20244, 20100, 20084, 20704, 20688, 20682, 20044, 20094,
#        20124, 20114, 20146, 20108, 20192, 20176, 20224, 20208, 20196,
#        20090, 20092, 20120, 20148, 20072, 20212, 20672, 20658, 20288,
#        20272, 20260, 20268, 20118, 20226, 20098, 20070, 20130, 20110,
#        20104, 20204, 20416, 20408, 20184, 20152, 20400, 20396, 20106,
#        20174, 20116, 20182, 20172, 20168, 20162, 20156, 20132, 20138,
#        20122, 20352, 20342, 20166, 20170, 20320, 20304, 20180, 20154,
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv("/Users/inviforce/Downloads/VS_CODE(C++,PYTHON,JUPYTER,DEV)/Sih_features_extracted/updated_csv_full_parallel_10000.csv",header=None)

# %%
df[3].apply(len).unique()
# Out:
# array([20032,   128,    64, 20020, 20026, 20064, 20056, 20016, 20004,
#        20048, 20040, 20000, 20096, 20080, 20068, 20160, 20144, 20140,
#        20006, 20012, 20034, 20060, 20022, 20014, 20024, 20062, 20002,
#        20086, 20010, 20082, 20036, 20088, 20030, 20008, 20038, 20066,
#        20018, 20058, 20042, 20052, 20054, 20050, 20078, 20074, 20028,
#        20076, 20128, 20112, 20102, 20046, 20256, 20240, 20232, 20136,
#        20126, 20244, 20100, 20084, 20704, 20688, 20682, 20044, 20094,
#        20124, 20114, 20146, 20108, 20192, 20176, 20224, 20208, 20196,
#        20090, 20092, 20120, 20148, 20072, 20212, 20672, 20658, 20288,
#        20272, 20260, 20268, 20118, 20226, 20098, 20070, 20130, 20110,
#        20104, 20204, 20416, 20408, 20184, 20152, 20400, 20396, 20106,
#        20174, 20116, 20182, 20172, 20168, 20162, 20156, 20132, 20138,
#        20122, 20352, 20342, 20166, 20170, 20320, 20304, 20180, 20154,
# ...

# %%
new_df=pd.read_csv("/Users/inviforce/Downloads/VS_CODE(C++,PYTHON,JUPYTER,DEV)/Sih_features_extracted/updated_csv_full_parallel_10000.csv",header=None)

# %%
new_df[3].apply(len).unique()
# Out:
# array([20032,   128,    64, 20020, 20026, 20064, 20056, 20016, 20004,
#        20048, 20040, 20000, 20096, 20080, 20068, 20160, 20144, 20140,
#        20006, 20012, 20034, 20060, 20022, 20014, 20024, 20062, 20002,
#        20086, 20010, 20082, 20036, 20088, 20030, 20008, 20038, 20066,
#        20018, 20058, 20042, 20052, 20054, 20050, 20078, 20074, 20028,
#        20076, 20128, 20112, 20102, 20046, 20256, 20240, 20232, 20136,
#        20126, 20244, 20100, 20084, 20704, 20688, 20682, 20044, 20094,
#        20124, 20114, 20146, 20108, 20192, 20176, 20224, 20208, 20196,
#        20090, 20092, 20120, 20148, 20072, 20212, 20672, 20658, 20288,
#        20272, 20260, 20268, 20118, 20226, 20098, 20070, 20130, 20110,
#        20104, 20204, 20416, 20408, 20184, 20152, 20400, 20396, 20106,
#        20174, 20116, 20182, 20172, 20168, 20162, 20156, 20132, 20138,
#        20122, 20352, 20342, 20166, 20170, 20320, 20304, 20180, 20154,
# ...

# %%
new_df=
