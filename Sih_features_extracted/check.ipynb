# %%
import pandas as pd

# %%
df=pd.read_csv("new_df1_12.csv")

# %%
pd.set_option('display.max_rows', None)

# %%
import pandas as pd

# Set pandas display options
pd.set_option('display.max_rows', None)  # Display all rows
pd.set_option('display.max_columns', None)  # Display all columns
pd.set_option('display.max_colwidth', None)  # No truncation of column values

# Example: Display a DataFrame
df.columns
# Out:
# Index(['0', '1', '2', '3', 'algorithm', '4', 'entropy_128',
#        'frequency_deviation_128', 'mean_run_0_128', 'mean_run_1_128',
#        ...
#        'bit_pair_freq_01_4096', 'bit_pair_freq_10_4096',
#        'bit_pair_freq_11_4096', 'entropy_gradient_mean_4096',
#        'entropy_gradient_std_4096', 'adjacent_bit_probability_4096',
#        'spectral_entropy_4096', 'dominant_frequency_magnitude_4096',
#        'power_spectral_peak_mean_4096', 'power_spectral_peak_std_4096'],
#       dtype='object', length=301)

# %%
import pandas as pd

# %%
df=pd.read_csv("updated_csv_full_parallel_10000.csv",header=None)

# %%
# Display the first 5 rows and columns starting from the 6th column
print(df.iloc[:5, 5:])
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...
